# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
import pandas as pd

# 環境変数の取得
load_dotenv()

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# 1. Excelファイルを読み込む
df = pd.read_excel('サンプルデータ.xlsx', sheet_name='売上データ')
# データフレームを表示して確認
df.head()

# 2. データをLLM用にテキスト形式に変換
# データフレーム全体を文字列に変換
sales_data_text = df.astype(str)
prompt_text = f"売上データ:\n{sales_data_text}\nこの売上データの傾向を分析してください。"
# 表示して確認
print(prompt_text)

# 3. OpenAI APIの呼び出し

# 役割を設定
role = "あなたはマーケティング分野に精通したデータサイエンティストです。企業の成長をサポートするために、効果的なインサイトを提供します。"

# APIへリクエスト
response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {"role": "system", "content": role},
        {"role": "user", "content": prompt_text},
    ],
)

# LLMからの回答を表示
print(response.choices[0].message.content.strip())

# 4. 分析結果をデータフレームに変換
result_list = response.choices[0].message.content.strip().split("\n")
df_out = pd.DataFrame(result_list, columns=['結果'])
print(df_out)

# 5. 結果をExcelファイルに保存
df_out.to_excel("売上データ分析結果.xlsx", index=False)
# Out:
# 売上データ:
#     カテゴリー 商品コード      商品名         売上日    単価   数量    原価
# 0      食品  1001      りんご  2023-01-01   200   50   120
# 1      食品  1002      バナナ  2023-01-01   150  100    80
# 2      食品  1003       牛乳  2023-01-02   180   80   100
# 3      衣服  2001     Tシャツ  2023-01-02  1500   20   800
# 4      衣服  2002     ジーンズ  2023-01-03  5000   10  2500
# ..    ...   ...      ...         ...   ...  ...   ...
# 235    衣服  2077   レインパンツ  2023-04-28  2000   18  1000
# 236    食品  1085      ザクロ  2023-04-29   600   40   300
# 237   日用品  3077    バスブラシ  2023-04-29   400   60   200
# 238    衣服  2078  レインシューズ  2023-04-30  2500   15  1250
# 239    食品  1086    ココナッツ  2023-04-30   300   80   150
#
# [240 rows x 7 columns]
# この売上データの傾向を分析してください。
# この売上データは、日時別の売上情報が含まれており、食品、衣服、日用品という異なるカテゴリに分かれています。トレンドを分析するために、以下のポイントに注目します。
#
# ### 1. カテゴリー別売上の傾向
# - **食品**: 売上数や収益が高いと考えられます。特に人気のある商品や季節ごとのトレンドを確認する必要があります。
# - **衣服**: 高単価の製品が多いため、利益率が良い可能性がありますが、数量は少ないかもしれません。衣服に関連する季節性（例：夏や冬の新作）を考慮することも重要です。
# - **日用品**: 利用頻度が高く、安定した売上が見込まれるカテゴリです。特定の商品が売上の大部分を占める可能性があります。
#
# ### 2. 売上日別のトレンド
# - 売上がどの日に集中しているかを観察することで、特定のプロモーションや販売戦略の影響を評価できます。たとえば、週末や祝日、セール期間中の売上増加の傾向があるかもしれません。
#
# ### 3. 商品別パフォーマンス
# - 単価と数量を考慮して各商品の利益率を計算し、最も収益性の高い商品を特定します。利益率の高い商品を推奨することで、売上をさらに伸ばすことが可能です。
#
# ### 4. 原価と利益の分析
# - 原価と売上を比較することで、各商品の利益率を分析し、非効率な商品（利益率が低いが売上が高いなど）を見つけることができます。これにより、値上げ、原価削減、もしくはマーケティング戦略を再検討する必要があるかもしれません。
#
# ### 5. 季節性やトレンドの確認
# - データを月別または四半期別に集計し、季節的なトレンドがあるかどうかを調べます。特定の季節に売上のピークがあるのか、逆に閑散期があるのかを把握することが重要です。
#
# ### 6. 顧客の購買行動
# - 購入頻度やリピート率の分析を行い、顧客のロイヤルティを測定します。また、新規顧客とリピーターの比率を確認し、マーケティング戦略を適切に調整します。
#
# ### 結論
# これらの分析を通じて、どのカテゴリーや商品が最も利益を生み出しているのか、また市場トレンドに基づいた具体的な販売戦略を策定できると思います、より深く分析を行うために可視化ツールを使ったグラフ作成や詳細な変化のログ分析も効果的です。これにより、戦略的なマーケティング方針を設定し、成長を支援するためのインサイトを提供することができます。
#                                                    結果
# 0   この売上データは、日時別の売上情報が含まれており、食品、衣服、日用品という異なるカテゴリに分...
# 1
# 2                                  ### 1. カテゴリー別売上の傾向
# 3   - **食品**: 売上数や収益が高いと考えられます。特に人気のある商品や季節ごとのトレンド...
# 4   - **衣服**: 高単価の製品が多いため、利益率が良い可能性がありますが、数量は少ないかも...
# 5   - **日用品**: 利用頻度が高く、安定した売上が見込まれるカテゴリです。特定の商品が売上...
# 6
# 7                                    ### 2. 売上日別のトレンド
# 8   - 売上がどの日に集中しているかを観察することで、特定のプロモーションや販売戦略の影響を評価...
# 9
# 10                                  ### 3. 商品別パフォーマンス
# 11  - 単価と数量を考慮して各商品の利益率を計算し、最も収益性の高い商品を特定します。利益率の高...
# 12
# 13                                    ### 4. 原価と利益の分析
# 14  - 原価と売上を比較することで、各商品の利益率を分析し、非効率な商品（利益率が低いが売上が高...
# 15
# 16                                 ### 5. 季節性やトレンドの確認
# 17  - データを月別または四半期別に集計し、季節的なトレンドがあるかどうかを調べます。特定の季節...
# 18
# 19                                     ### 6. 顧客の購買行動
# 20  - 購入頻度やリピート率の分析を行い、顧客のロイヤルティを測定します。また、新規顧客とリピー...
# 21
# 22                                             ### 結論
# 23  これらの分析を通じて、どのカテゴリーや商品が最も利益を生み出しているのか、また市場トレンドに...
