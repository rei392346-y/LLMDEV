# %% [markdown]
# # 参考：スタブとモック
# スタブ（stub）と モック（mock）は、テスト対象のプログラムが依存する「他のコードや外部サービス」を模擬するために使われる技術です。
#
# これらはテストの際、未完成の外部サービスを代替したり、外部サービスに左右されることなく、安定したテストを行うために使用します。スタブは簡易的な模倣、モックはより高機能な模倣となります。
#
# - スタブ ：依存関係を最低限の実装で置き換え、テストが実行されるようにするもの
# - モック ：より高機能に呼び出しや振る舞いを追跡し、期待する呼び出しが行われたかを検証できるもの
